# %%
import torch

print(torch.__version__)
# Out:
# 2.8.0+cu128

# %%
torch.get_default_dtype()
# Out:
# torch.float32

# %%
torch.set_default_dtype(torch.float64)
torch.get_default_dtype()
# Out:
# torch.float64

# %%
torch.get_default_dtype()
# Out:
# torch.float64
